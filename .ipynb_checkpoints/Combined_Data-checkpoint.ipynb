# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import gmaps
# from api_keys import g_key
from ipywidgets.embed import embed_minimal_html

# %%
toronto= pd.read_csv('Toronto/Output/toronto_table.csv')
new_york=pd.read_csv('New York/Output/NY_table.csv')
montreal = pd.read_csv('montreal/Output/final_montreal.csv')

# %%
toronto
# Out:
#                      Neighbourhood  Number of Collisions  Median Income  \
# 0     Runnymede-Bloor West Village                     3        93586.0
# 1              Mount Pleasant East                     3        93566.0
# 2                        Casa Loma                     2        93022.0
# 3     Banbury-Don Mills/York Mills                     9        90620.0
# 4   Eringate-Centennial-West Deane                     2        88872.0
# ..                             ...                   ...            ...
# 85                 Flemingdon Park                     7        48917.0
# 86             Bay Street Corridor                     6        48737.0
# 87                          Weston                     2        45696.0
# 88            Kensington-Chinatown                    10        44216.0
# 89             North St.James Town                     2        41016.0
#
#                  District  Population     City
# 0   Toronto and East York    111006.0  Toronto
# 1   Toronto and East York     11463.0  Toronto
# 2   Toronto and East York     31165.0  Toronto
# 3              North York     38133.0  Toronto
# 4          Etobicoke York     22372.0  Toronto
# ..                    ...         ...      ...
# 85            Scarborough     43041.0  Toronto
# 86  Toronto and East York     43466.0  Toronto
# 87         Etobicoke York     29090.0  Toronto
# 88  Toronto and East York     17945.0  Toronto
# 89  Toronto and East York     18675.0  Toronto
#
# [90 rows x 6 columns]

# %%
new_york
# Out:
#    Neighbourhood  Number of Collisions  Median Income  Population      City
# 0          BRONX                    63       47987.10     1432132  New York
# 1       BROOKLYN                   142       70578.90     2582830  New York
# 2      MANHATTAN                    91      103898.34     1628701  New York
# 3         QUEENS                   148       81883.62     2278906  New York
# 4  STATEN ISLAND                    26       99876.42      476179  New York

# %%
montreal = montreal.dropna(how='any')
montreal = montreal.drop('Unnamed: 0',axis=1)

# %%
montreal['Population'].astype(float)
# Out:
# 0       32448.0
# 1       48899.0
# 2       18980.0
# 3        6973.0
# 4       20151.0
# 5       20276.0
# 6     1704694.0
# 7        3850.0
# 8        5050.0
# 9       31380.0
# 10       4958.0
# 11      20312.0
# Name: Population, dtype: float64

# %%
toronto['Collisions per 1000 people']=(toronto['Number of Collisions']/toronto['Population'])*1000
toronto
# Out:
#                      Neighbourhood  Number of Collisions  Median Income  \
# 0     Runnymede-Bloor West Village                     3        93586.0
# 1              Mount Pleasant East                     3        93566.0
# 2                        Casa Loma                     2        93022.0
# 3     Banbury-Don Mills/York Mills                     9        90620.0
# 4   Eringate-Centennial-West Deane                     2        88872.0
# ..                             ...                   ...            ...
# 85                 Flemingdon Park                     7        48917.0
# 86             Bay Street Corridor                     6        48737.0
# 87                          Weston                     2        45696.0
# 88            Kensington-Chinatown                    10        44216.0
# 89             North St.James Town                     2        41016.0
#
#                  District  Population     City  Collisions per 1000 people
# 0   Toronto and East York    111006.0  Toronto                    0.027026
# 1   Toronto and East York     11463.0  Toronto                    0.261712
# 2   Toronto and East York     31165.0  Toronto                    0.064175
# 3              North York     38133.0  Toronto                    0.236016
# 4          Etobicoke York     22372.0  Toronto                    0.089397
# ..                    ...         ...      ...                         ...
# 85            Scarborough     43041.0  Toronto                    0.162636
# 86  Toronto and East York     43466.0  Toronto                    0.138039
# 87         Etobicoke York     29090.0  Toronto                    0.068752
# 88  Toronto and East York     17945.0  Toronto                    0.557258
# 89  Toronto and East York     18675.0  Toronto                    0.107095
#
# [90 rows x 7 columns]

# %%
new_york['Collisions per 1000 people']=(new_york['Number of Collisions']/new_york['Population'])*1000
new_york
# Out:
#    Neighbourhood  Number of Collisions  Median Income  Population      City  \
# 0          BRONX                    63       47987.10     1432132  New York
# 1       BROOKLYN                   142       70578.90     2582830  New York
# 2      MANHATTAN                    91      103898.34     1628701  New York
# 3         QUEENS                   148       81883.62     2278906  New York
# 4  STATEN ISLAND                    26       99876.42      476179  New York
#
#    Collisions per 1000 people
# 0                    0.043990
# 1                    0.054978
# 2                    0.055873
# 3                    0.064943
# 4                    0.054601

# %%
montreal['Collisions per 1000 people']=(montreal['Number of Collisions']/montreal['Population'])*1000
montreal
# Out:
#              Neighbourhoods  Number of Collisions  Median Income  Population  \
# 0            Côte-Saint-Luc                   2.0        58935.0     32448.0
# 1       Dollard-Des Ormeaux                   2.0        78981.0     48899.0
# 2                    Dorval                   3.0        64689.0     18980.0
# 3                 Hampstead                   2.0       122496.0      6973.0
# 4                  Kirkland                   2.0       115381.0     20151.0
# 5                Mont-Royal                   1.0       109540.0     20276.0
# 6                  Montréal                 155.0        50227.0   1704694.0
# 7              Montréal-Est                   2.0        50318.0      3850.0
# 8            Montréal-Ouest                   2.0       115029.0      5050.0
# 9             Pointe-Claire                   4.0        80242.0     31380.0
# 10  Sainte-Anne-de-Bellevue                   2.0        67200.0      4958.0
# 11                Westmount                   2.0       100153.0     20312.0
#
#         City  Collisions per 1000 people
# 0   Montreal                    0.061637
# 1   Montreal                    0.040901
# 2   Montreal                    0.158061
# 3   Montreal                    0.286821
# 4   Montreal                    0.099251
# 5   Montreal                    0.049319
# 6   Montreal                    0.090925
# 7   Montreal                    0.519481
# 8   Montreal                    0.396040
# 9   Montreal                    0.127470
# 10  Montreal                    0.403388
# 11  Montreal                    0.098464

# %%
x_axis = toronto['Median Income']
y_axis = toronto['Collisions per 1000 people']
plt.scatter(x_axis,y_axis,c='lightblue',alpha=0.75)
x_axis = new_york['Median Income']
y_axis = new_york['Collisions per 1000 people']
plt.scatter(x_axis,y_axis,c='green',alpha=0.75)
x_axis = montreal['Median Income']
y_axis = montreal['Collisions per 1000 people']
plt.scatter(x_axis,y_axis,c='red',alpha=0.75)
plt.show()
