# %%
import pandas as pd
import gmaps
from api_keys import g_key

# %%
toronto_collision= pd.read_csv('Resources/Fatal_Collisions_toronto.csv')

# %%
toronto_collision.head()
# Out:
#            X          Y    Index_      ACCNUM  YEAR                      DATE  \
# 0 -79.227590  43.816245   7377669     1275814  2012  2012-01-12T05:00:00.000Z
# 1 -79.447742  43.637614  80000014   131058335  2013  2013-11-29T05:00:00.000Z
# 2 -79.259883  43.716773  80944448  8001077165  2018  2018-06-14T04:00:00.000Z
# 3 -79.316890  43.821345   6253540     1162012  2010  2010-04-13T04:00:00.000Z
# 4 -79.574641  43.728129  80501551  4003267619  2014  2014-11-09T05:00:00.000Z
#
#    TIME  Hour                 STREET1          STREET2  ... EMERG_VEH  \
# 0   558     5              NEILSON RD      FINCH AVE E  ...
# 1   558     5  1491 LAKE SHORE BLVD W                   ...
# 2   558     5          ST CLAIR AVE E      DANFORTH RD  ...
# 3   559     5           STEELES AVE E    BIRCHMOUNT RD  ...
# 4   559     5             KIPLING AVE  WESTHUMBER BLVD  ...
#
#   PASSENGER SPEEDING  AG_DRIV  REDLIGHT  ALCOHOL  DISABILITY  Hood_ID  \
# 0       Yes               Yes                                     132
# 1                Yes      Yes                                      85
# 2                         Yes                                     120
# 3       Yes               Yes       Yes                  Yes      116
# 4       Yes               Yes       Yes                             4
#
#                   Neighbourh  ObjectId
# 0              Malvern (132)         1
# 1        South Parkdale (85)         2
# 2  Clairlea-Birchmount (120)         3
# 3              Steeles (116)         4
# 4        Rexdale-Kipling (4)         5
#
# [5 rows x 60 columns]

# %%
toronto_collision.columns
# Out:
# Index(['X', 'Y', 'Index_', 'ACCNUM', 'YEAR', 'DATE', 'TIME', 'Hour', 'STREET1',
#        'STREET2', 'OFFSET', 'ROAD_CLASS', 'District', 'WardNum', 'WardNum_X',
#        'WardNum_Y', 'Division', 'Division_X', 'Division_Y', 'LATITUDE',
#        'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'LIGHT',
#        'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE', 'INJURY',
#        'FATAL_NO', 'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND',
#        'PEDTYPE', 'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT', 'CYCCOND',
#        'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK',
#        'TRSN_CITY_', 'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV',
#        'REDLIGHT', 'ALCOHOL', 'DISABILITY', 'Hood_ID', 'Neighbourh',
#        'ObjectId'],
#       dtype='object')

# %%
toronto_collision=toronto_collision[['X', 'Y', 'District','YEAR', 'VEHTYPE','DATE', 'Hour', 'ROAD_CLASS', 'RDSFCOND','REDLIGHT','ALCOHOL','AG_DRIV',
       'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK']]

# %%
toronto_collision=toronto_collision.rename(columns={'X':'Longitude',
                                                    'Y':'Latitude',
                                                    'YEAR':'Year',
                                                    'VEHTYPE':'Vehicle Type',
                                                    'DATE':'Date', 
                                                    'ROAD_CLASS':'Road Type', 
                                                    'RDSFCOND':'Road Conditions',
                                                    'REDLIGHT':'Red Light',
                                                    'ALCOHOL':'Alcohol',
                                                    'AG_DRIV':'Aggressive/Distracted Driving',
                                                    'PEDESTRIAN':'Pedestrian', 
                                                    'CYCLIST':'Cyclist', 
                                                    'AUTOMOBILE':'Automobile', 
                                                    'MOTORCYCLE':'Motorcycle', 
                                                    'TRUCK':'Truck'})

# %%
#sort data by year
toronto_collision=toronto_collision.sort_values('Year',ascending=False)

# %%
toronto_collision.loc[toronto_collision['Alcohol']=='Yes'].head()
# Out:
#      Longitude   Latitude               District  Year  \
# 348 -79.529720  43.681620         Etobicoke York  2018
# 482 -79.512874  43.599005         Etobicoke York  2018
# 148 -79.398158  43.658187  Toronto and East York  2018
# 290 -79.269771  43.711009            Scarborough  2017
# 175 -79.472667  43.633498  Toronto and East York  2017
#
#                   Vehicle Type                      Date  Hour  \
# 348  Automobile, Station Wagon  2018-01-07T05:00:00.000Z    18
# 482                             2018-05-15T04:00:00.000Z    22
# 148                             2018-03-15T04:00:00.000Z     2
# 290                             2017-09-28T04:00:00.000Z    16
# 175  Automobile, Station Wagon  2017-01-29T05:00:00.000Z     3
#
#           Road Type Road Conditions Red Light Alcohol  \
# 348  Major Arterial           Other               Yes
# 482  Major Arterial                               Yes
# 148  Major Arterial             Dry               Yes
# 290  Minor Arterial             Dry               Yes
# 175      Expressway             Dry               Yes
#
#     Aggressive/Distracted Driving Pedestrian Cyclist Automobile Motorcycle  \
# 348                           Yes                           Yes
# 482                           Yes                           Yes
# 148                           Yes        Yes                Yes
# 290                           Yes        Yes                Yes
# 175                           Yes                           Yes
#
#     Truck
# 348
# 482
# 148
# 290
# 175

# %%
toronto_collision.head()
# Out:
#      Longitude   Latitude               District  Year  \
# 155 -79.458270  43.650427  Toronto and East York  2018
# 52  -79.334277  43.666098  Toronto and East York  2018
# 348 -79.529720  43.681620         Etobicoke York  2018
# 349 -79.275096  43.730475            Scarborough  2018
# 252 -79.508113  43.719008             North York  2018
#
#                   Vehicle Type                      Date  Hour  \
# 155                 Motorcycle  2018-09-15T04:00:00.000Z     2
# 52                     Bicycle  2018-05-16T04:00:00.000Z     8
# 348  Automobile, Station Wagon  2018-01-07T05:00:00.000Z    18
# 349                             2018-01-09T05:00:00.000Z    18
# 252                             2018-04-13T04:00:00.000Z    15
#
#           Road Type Road Conditions Red Light Alcohol  \
# 155  Major Arterial             Dry
# 52   Minor Arterial             Dry
# 348  Major Arterial           Other               Yes
# 349  Major Arterial             Wet
# 252  Major Arterial
#
#     Aggressive/Distracted Driving Pedestrian Cyclist Automobile Motorcycle  \
# 155                                                         Yes        Yes
# 52                            Yes                Yes
# 348                           Yes                           Yes
# 349                                      Yes                Yes
# 252                           Yes        Yes                Yes
#
#     Truck
# 155
# 52    Yes
# 348
# 349
# 252

# %%
#save cleaned data to csv
toronto_collision.to_csv('Resources/toronto_cleaned.csv', index=False)

# %%
#Time PATTERNS
print('Create bins for time of accident.')
print('They are separated first into 4 hour sections:')
print('midnight: 12am-4am, Early Morning: 4am-8am, Morning: 8am-12pm, Afternoon: 12pm-4pm, Evening: 4pm-8pm, Night:8-midnight')
# Out:
# Create bins for time of accident.
# They are separated first into 4 hour sections:
# midnight: 12am-4am, Early Morning: 4am-8am, Morning: 8am-12pm, Afternoon: 12pm-4pm, Evening: 4pm-8pm, Night:8-midnight

# %%
#Bin times, compare the collision rates, correlation with alcohol consumption
bins= [x for x in range(0,26,4)]
print(bins)
group_names = ['Midnight', 'Early Morning', 'Morning', 'Afternoon','Evening','Night']
# Out:
# [0, 4, 8, 12, 16, 20, 24]

# %%
yyzcollision_time=toronto_collision

# %%
yyzcollision_time["Time Summary"] = pd.cut(yyzcollision_time["Hour"], bins, labels=group_names)
yyzcollision_time.groupby('Time Summary').min()
# Out:
#                Longitude   Latitude        District  Year Vehicle Type  \
# Time Summary
# Midnight      -79.589862  43.622645  Etobicoke York  2008
# Early Morning -79.617862  43.593039  Etobicoke York  2008
# Morning       -79.612010  43.599963  Etobicoke York  2008
# Afternoon     -79.620990  43.599353  Etobicoke York  2008
# Evening       -79.619815  43.594345  Etobicoke York  2008
# Night         -79.592790  43.599005                  2008
#
#                                    Date  Hour  Road Type Road Conditions  \
# Time Summary
# Midnight       2008-04-13T04:00:00.000Z     1  Collector
# Early Morning  2008-01-08T05:00:00.000Z     5  Collector
# Morning        2008-02-28T05:00:00.000Z     9  Collector
# Afternoon      2008-01-31T05:00:00.000Z    13  Collector
# Evening        2008-01-05T05:00:00.000Z    17  Collector
# Night          2008-02-24T05:00:00.000Z    21  Collector
#
#               Red Light Alcohol Aggressive/Distracted Driving Pedestrian  \
# Time Summary
# Midnight
# Early Morning
# Morning
# Afternoon
# Evening
# Night
#
#               Cyclist Automobile Motorcycle Truck
# Time Summary
# Midnight
# Early Morning
# Morning
# Afternoon
# Evening
# Night

# %%
# check if there is trend for data
toronto_collision
#Bin times, compare the collision rates, correlation with alcohol consumption
bins= [x for x in range(0,24)]
len(bins)
group_names = ['one', 'two', 'three','four','five','six','seven','eight',
               'nine','ten','eleven','noon','oneaft','twoaft','threeaft','fouraft','fiveeven','sixeve','seveneve','eighteve','nineve','teneve','elvel']

# %%
toronto_collision["All Time"] = pd.cut(toronto_collision["Hour"], bins, labels=group_names)

toronto_collision.head(50)
# Out:
#      Longitude   Latitude               District  Year  \
# 155 -79.458270  43.650427  Toronto and East York  2018
# 52  -79.334277  43.666098  Toronto and East York  2018
# 348 -79.529720  43.681620         Etobicoke York  2018
# 349 -79.275096  43.730475            Scarborough  2018
# 252 -79.508113  43.719008             North York  2018
# 350 -79.202304  43.783129            Scarborough  2018
# 271 -79.350383  43.718589             North York  2018
# 274 -79.458881  43.637709  Toronto and East York  2018
# 413 -79.350940  43.658515  Toronto and East York  2018
# 248 -79.452075  43.702281             North York  2018
# 110 -79.536220  43.753218         Etobicoke York  2018
# 174 -79.499957  43.623107         Etobicoke York  2018
# 482 -79.512874  43.599005         Etobicoke York  2018
# 358 -79.299571  43.800383            Scarborough  2018
# 329 -79.232578  43.741534            Scarborough  2018
# 172 -79.577121  43.705172         Etobicoke York  2018
# 121 -79.413097  43.777663             North York  2018
# 364 -79.282741  43.773322            Scarborough  2018
# 429 -79.292499  43.782229            Scarborough  2018
# 570 -79.491092  43.724532             North York  2018
# 125 -79.439349  43.697970  Toronto and East York  2018
# 82  -79.254787  43.706175            Scarborough  2018
# 263 -79.306857  43.818522            Scarborough  2018
# 90  -79.402156  43.725032             North York  2018
# 328 -79.383662  43.684390  Toronto and East York  2018
# 88  -79.307048  43.823569            Scarborough  2018
# 554 -79.382091  43.649542  Toronto and East York  2018
# 501 -79.213535  43.814105            Scarborough  2018
# 463                                      Yes                Yes
# 276                                      Yes                Yes
# 295                           Yes        Yes
# 390                           Yes        Yes                Yes
# 382                                      Yes                Yes
# 304                                      Yes                Yes
#
#     Truck   Time Summary  All Time
# 155             Midnight       two
# 52    Yes  Early Morning     eight
# 348              Evening    sixeve
# 349              Evening    sixeve
# 252            Afternoon  threeaft
# 350              Evening    sixeve
# 271   Yes      Afternoon  threeaft
# 274            Afternoon  threeaft
# 413              Evening  eighteve
# 248            Afternoon  threeaft
# 110                  NaN       NaN
# 174             Midnight     three
# 482                Night    teneve
# 358              Evening    sixeve
# 329              Evening  fiveeven
# 172   Yes       Midnight     three
# 121                  NaN       NaN
# 364   Yes        Evening    sixeve
# 429              Evening  eighteve
# 570              Morning      noon
# 125   Yes            NaN       NaN
# 82               Morning      nine
# 263            Afternoon  threeaft
# 90               Morning      nine
# 328              Evening  fiveeven
# 88               Morning      nine
# 554              Morning    eleven
# 501                Night     elvel
# 557              Morning    eleven
# 506                Night     elvel
# 569              Morning      noon
# 424              Evening  eighteve
# 519              Morning       ten
# 257            Afternoon  threeaft
# 494                Night     elvel
# 565   Yes        Morning      noon
# 339              Evening    sixeve
# 490                Night     elvel
# 122                  NaN       NaN
# 94               Morning      nine
# 275            Afternoon   fouraft
# 148             Midnight       two
# 15         Early Morning       six
# 222            Afternoon    twoaft
# 463                Night    nineve
# 276            Afternoon   fouraft
# 295   Yes      Afternoon   fouraft
# 390              Evening  seveneve
# 382              Evening  seveneve
# 304              Evening  fiveeven

# %%
toronto_collision_hour=toronto_collision.groupby("Hour")

# %%
alcohol = (toronto_collision_hour
         .apply(lambda x: (x['Alcohol']== 'Yes').sum())
         .reset_index(name='Alcohol count'))

alcohol
# Out:
#     Hour  Alcohol count
# 0      0              5
# 1      1              1
# 2      2              6
# 3      3              5
# 4      4              0
# 5      5              0
# 6      6              0
# 7      7              1
# 8      8              0
# 9      9              0
# 10    10              0
# 11    11              0
# 12    12              0
# 13    13              0
# 14    14              0
# 15    15              1
# 16    16              1
# 17    17              0
# 18    18              3
# 19    19              0
# 20    20              0
# 21    21              1
# 22    22              2
# 23    23              4

# %%
# use google maps to create heat map
gmaps.configure(api_key=g_key)
# Out:
# 'AIzaSyBjMJMlvoC4AqGQl2PbH3TgSZDqqcnKb6I'

# %%
# Store 'Latitude' and 'Longitude' into  df 
locations_year = toronto_collision[["Latitude", "Longitude", 'Year']].astype(float)
locations_year['Rounded Latitude']=round(locations.loc[:,'Latitude'],1)
locations_year['Rounded Longitude']=round(locations.loc[:,'Longitude'],1)
locations_year['Weight']=''

locations_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3117bb2fdbd4> in <module>
#       1 # Store 'Latitude' and 'Longitude' into  df
#       2 locations_year = toronto_collision[["Latitude", "Longitude", 'Year']].astype(float)
# ----> 3 locations_year['Rounded Latitude']=round(locations.loc[:,'Latitude'],1)
#       4 locations_year['Rounded Longitude']=round(locations.loc[:,'Longitude'],1)
#       5 locations_year['Weight']=''
#
# NameError: name 'locations' is not defined

# %%
groupedlocations= locations_year.groupby(['YEAR','Rounded Latitude','Rounded Longitude'])
groupedlocations.count()

# %%
locations = toronto_collision[["Latitude", "Longitude"]].astype(float)
fig = gmaps.figure(map_type='HYBRID')
heatmap_layer = gmaps.heatmap_layer(locations)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
