# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import gmaps
from api_keys import g_key
from ipywidgets.embed import embed_minimal_html

# %%
toronto= pd.read_csv('Toronto/Output/toronto_table.csv')
new_york=pd.read_csv('New York/Output/NY_table.csv')

# %%
toronto
# Out:
#            Neighbourhood  Number of Collisions  Median Income  \
# 0    Lawrence Park South                     4       151885.0
# 1         Kingsway South                     1       151552.0
# 2    Lawrence Park North                     2       144963.0
# 3     Leaside-Bennington                     4       126930.0
# 4      Forest Hill South                     3       119484.0
# ..                   ...                   ...            ...
# 95       Flemingdon Park                     7        48917.0
# 96   Bay Street Corridor                     6        48737.0
# 97                Weston                     2        45696.0
# 98  Kensington-Chinatown                    10        44216.0
# 99   North St.James Town                     2        41016.0
#
#                  District  Population     City
# 0              North York     16828.0  Toronto
# 1          Etobicoke York      9271.0  Toronto
# 2              North York     15179.0  Toronto
# ...

# %%
new_york
# Out:
#    Neighbourhood  Number of Collisions   Latitude  Longitude  Median Income  \
# 0          BRONX                    63  40.906340 -73.896492        38085.0
# 1       BROOKLYN                   142  40.615204 -73.963362        56015.0
# 2      MANHATTAN                    91  40.757233 -73.976047        82459.0
# 3         QUEENS                   148  40.666396 -73.751759        64987.0
# 4  STATEN ISLAND                    26  40.543870 -74.144443        79267.0
#
#    Population      City
# 0     1432132  New York
# 1     2582830  New York
# 2     1628701  New York
# 3     2278906  New York
# 4      476179  New York

# %%
combined=toronto.append(new_york)

# %%
combined['Collisions per 1000 people']=(combined['Number of Collisions']/combined['Population'])*1000

# %%
combined
# Out:
#         City               District   Latitude  Longitude  Median Income  \
# 0    Toronto             North York  43.712046 -79.411693       151885.0
# 1    Toronto         Etobicoke York  43.657290 -79.509113       151552.0
# 2    Toronto             North York  43.725344 -79.402240       144963.0
# 3    Toronto  Toronto and East York  43.692008 -79.361987       126930.0
# 4    Toronto  Toronto and East York  43.699485 -79.424945       119484.0
# ..       ...                    ...        ...        ...            ...
# 0   New York                    NaN  40.906340 -73.896492        38085.0
# 1   New York                    NaN  40.615204 -73.963362        56015.0
# 2   New York                    NaN  40.757233 -73.976047        82459.0
# 3   New York                    NaN  40.666396 -73.751759        64987.0
# 4   New York                    NaN  40.543870 -74.144443        79267.0
#
#           Neighbourhood  Number of Collisions  Population  \
# ...

# %%
#bar chart for income
city= combined

# %%
x_axis=combined['Median Income']
y_axis=combined['Collisions per 1000 people']

# %%
plt.scatter(x_axis,y_axis)
